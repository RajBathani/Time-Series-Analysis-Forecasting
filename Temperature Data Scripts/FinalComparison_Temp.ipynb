# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/RAJ BATHANI/Downloads/TimeSeries Datasets/TEMP_FuturePrices_1month.csv",index_col = ['Date'], parse_dates = ['Date'])

# %%
df.head()
# Out:
#             Actual     AR     MA  ARIMA  Smoothing  Prophet
# Date
# 1991-01-01   15.12  13.15  13.48  12.98      13.84    14.92
# 1991-01-02   13.00  13.63  14.21  13.32      13.84    15.09
# 1991-01-03   14.10  13.70  13.82  13.48      13.84    15.01
# 1991-01-04   14.80  13.62  13.58  13.51      13.84    15.06
# 1991-01-05   18.40  13.48  13.34  13.49      13.84    15.09

# %%
df.plot(figsize=(10,5))

# %%
from sklearn.metrics import mean_squared_error 
from math import sqrt

# %%
AR = df['AR']
Actual = df['Actual']
MA = df['MA']
ARIMA = df['ARIMA']
Smoothing = df['Smoothing']
Prophet = df['Prophet']

# %%
rmse_AR = sqrt(mean_squared_error(AR, Actual))

# %%
rmse_AR
# Out:
# 2.3259372027137233

# %%
rmse_MA = sqrt(mean_squared_error(MA, Actual))

# %%
rmse_MA
# Out:
# 2.3321974962018803

# %%
rmse_ARIMA = sqrt(mean_squared_error(ARIMA, Actual))

# %%
rmse_ARIMA
# Out:
# 2.3032354522252163

# %%
rmse_Smoothing = sqrt(mean_squared_error(Smoothing, Actual))

# %%
rmse_Smoothing
# Out:
# 2.075502271118814

# %%
rmse_Prophet = sqrt(mean_squared_error(Prophet, Actual))

# %%
rmse_Prophet
# Out:
# 2.21699593318119
